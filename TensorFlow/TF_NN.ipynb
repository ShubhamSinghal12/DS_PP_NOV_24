# %% [markdown]
# # TensorFlow NN
# - Sequential
# - Functional
# - Flow: Make the model, Complie, Fit, Predict, Evaluate, Visualization of loss and acc

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

# %%
X,y = make_circles(1000,noise = 0.03)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
import numpy as np

def plot_decision_boundary(model, X, y):
  """
  Plots the decision boundary created by a model predicting on X.
  This function has been adapted from two phenomenal resources:
   1. CS231n - https://cs231n.github.io/neural-networks-case-study/
   2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
  """
  # Define the axis boundaries of the plot and create a meshgrid
  x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
  y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
  xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))

  # Create X values (we're going to predict on all of these)
  x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html

  # Make predictions using the trained model
  y_pred = model.predict(x_in)

  # Check for multi-class
  if model.output_shape[-1] > 1: # checks the final dimension of the model's output shape, if this is > (greater than) 1, it's multi-class
    print("doing multiclass classification...")
    # We have to reshape our predictions to get them ready for plotting
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
  else:
    print("doing binary classifcation...")
    y_pred = np.round(np.max(y_pred, axis=1)).reshape(xx.shape)

  # Plot decision boundary
  plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
  plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train,y_test = train_test_split(X,y,train_size=0.8)
print(x_train.shape,x_test.shape)
# Out:
# (800, 2) (200, 2)

# %%
# y_train = tf.one_hot(y_train,depth=2)
# y_test = tf.one_hot(y_test,depth=2)

# print(y_train.shape,y_test.shape)
# Out:
# (800, 2) (200, 2)

# %%
# model = keras.Sequential([
#     layers.Input(shape=(2,)),
#     layers.Dense(16,activation='relu'),
#     layers.Dense(8,activation='relu'),
#     layers.Dense(4,activation='relu'),
#     layers.Dense(2,activation='softmax')
# ])

# print(model.summary())


model = keras.Sequential()
model.add(keras.Input(shape=(2,)))
model.add(layers.Dense(10,activation='relu'))
model.add(layers.Dense(20,activation='relu'))
model.add(layers.Dense(10,activation='relu'))
model.add(layers.Dense(1,activation='sigmoid'))
print(model.summary())

model.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ["accuracy"]
)
history = model.fit(x_train,y_train,batch_size=80,epochs=100,validation_data=(x_test,y_test))
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_16 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4588 - loss: 0.7055 - val_accuracy: 0.4750 - val_loss: 0.6971
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4744 - loss: 0.6973 - val_accuracy: 0.4200 - val_loss: 0.6961
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4543 - loss: 0.6934 - val_accuracy: 0.4500 - val_loss: 0.6963
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5199 - loss: 0.6900 - val_accuracy: 0.4700 - val_loss: 0.6967
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5125 - loss: 0.6896 - val_accuracy: 0.4700 - val_loss: 0.6959
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5005 - loss: 0.6880 - val_accuracy: 0.4700 - val_loss: 0.6953
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5145 - loss: 0.6859 - val_accuracy: 0.4700 - val_loss: 0.6943
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5236 - loss: 0.6832 - val_accuracy: 0.4700 - val_loss: 0.6933
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5122 - loss: 0.6852 - val_accuracy: 0.4700 - val_loss: 0.6916
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5156 - loss: 0.6842 - val_accuracy: 0.5100 - val_loss: 0.6901
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5470 - loss: 0.6816 - val_accuracy: 0.5350 - val_loss: 0.6892
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5386 - loss: 0.6816 - val_accuracy: 0.5400 - val_loss: 0.6873
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5798 - loss: 0.6759 - val_accuracy: 0.5350 - val_loss: 0.6861
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5585 - loss: 0.6752 - val_accuracy: 0.5550 - val_loss: 0.6840
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5963 - loss: 0.6702 - val_accuracy: 0.5550 - val_loss: 0.6821
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5755 - loss: 0.6755 - val_accuracy: 0.6000 - val_loss: 0.6777
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6232 - loss: 0.6682 - val_accuracy: 0.6200 - val_loss: 0.6747
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5994 - loss: 0.6672 - val_accuracy: 0.6000 - val_loss: 0.6702
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6111 - loss: 0.6615 - val_accuracy: 0.6050 - val_loss: 0.6660
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6035 - loss: 0.6575 - val_accuracy: 0.6350 - val_loss: 0.6624
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6586 - loss: 0.6510 - val_accuracy: 0.6350 - val_loss: 0.6575
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6895 - loss: 0.6428 - val_accuracy: 0.7000 - val_loss: 0.6504
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7285 - loss: 0.6408 - val_accuracy: 0.7150 - val_loss: 0.6399
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7317 - loss: 0.6289 - val_accuracy: 0.7250 - val_loss: 0.6302
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7583 - loss: 0.6172 - val_accuracy: 0.7600 - val_loss: 0.6170
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7964 - loss: 0.6003 - val_accuracy: 0.8550 - val_loss: 0.6018
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8741 - loss: 0.5874 - val_accuracy: 0.8500 - val_loss: 0.5857
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8741 - loss: 0.5700 - val_accuracy: 0.9200 - val_loss: 0.5674
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9217 - loss: 0.5524 - val_accuracy: 0.9550 - val_loss: 0.5473
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9555 - loss: 0.5324 - val_accuracy: 0.9950 - val_loss: 0.5238
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9799 - loss: 0.5102 - val_accuracy: 0.9900 - val_loss: 0.5022
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9907 - loss: 0.4857 - val_accuracy: 1.0000 - val_loss: 0.4763
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9930 - loss: 0.4648 - val_accuracy: 0.9850 - val_loss: 0.4527
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9933 - loss: 0.4364 - val_accuracy: 1.0000 - val_loss: 0.4197
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9995 - loss: 0.4124 - val_accuracy: 0.9950 - val_loss: 0.3911
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9948 - loss: 0.3780 - val_accuracy: 1.0000 - val_loss: 0.3588
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.3485 - val_accuracy: 1.0000 - val_loss: 0.3307
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9969 - loss: 0.3228 - val_accuracy: 1.0000 - val_loss: 0.3065
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9993 - loss: 0.2875 - val_accuracy: 1.0000 - val_loss: 0.2781
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.2650 - val_accuracy: 1.0000 - val_loss: 0.2541
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9998 - loss: 0.2420 - val_accuracy: 1.0000 - val_loss: 0.2313
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.2182 - val_accuracy: 1.0000 - val_loss: 0.2107
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1991 - val_accuracy: 1.0000 - val_loss: 0.1922
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.1774 - val_accuracy: 1.0000 - val_loss: 0.1737
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1672 - val_accuracy: 1.0000 - val_loss: 0.1586
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.1494 - val_accuracy: 1.0000 - val_loss: 0.1469
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1464 - val_accuracy: 1.0000 - val_loss: 0.1337
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1224 - val_accuracy: 1.0000 - val_loss: 0.1226
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1135 - val_accuracy: 1.0000 - val_loss: 0.1120
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1034 - val_accuracy: 1.0000 - val_loss: 0.1043
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0974 - val_accuracy: 1.0000 - val_loss: 0.0950
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0881 - val_accuracy: 1.0000 - val_loss: 0.0876
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0830 - val_accuracy: 1.0000 - val_loss: 0.0819
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0721 - val_accuracy: 1.0000 - val_loss: 0.0763
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0727 - val_accuracy: 1.0000 - val_loss: 0.0710
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0646 - val_accuracy: 1.0000 - val_loss: 0.0673
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0586 - val_accuracy: 1.0000 - val_loss: 0.0621
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0597 - val_accuracy: 1.0000 - val_loss: 0.0596
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0545
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0495 - val_accuracy: 1.0000 - val_loss: 0.0517
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 1.0000 - val_loss: 0.0484
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0464 - val_accuracy: 1.0000 - val_loss: 0.0466
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0413 - val_accuracy: 1.0000 - val_loss: 0.0438
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0397 - val_accuracy: 1.0000 - val_loss: 0.0413
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 0.0402
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0379
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0330
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0311
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0270
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0255
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0247
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0243
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0223
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0217
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0201
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0182
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0139 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0120

# %%
model.evaluate(x_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0113
# [0.012032246217131615, 1.0]

# %%
ypred = model.predict(x_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# np.argmax(ypred,axis = 1)
# ypred

# %%
# plot_decision_boundary(model,x_train,np.argmax(y_train,axis=1))
plot_decision_boundary(model,x_train,y_train)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# doing binary classifcation...

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
plt.plot(history.history['accuracy'],label = 'accuracy')
plt.plot(history.history['loss'],label = 'loss')

plt.legend()
plt.xlabel('epochs')
plt.grid()
plt.show()

# %%
model.evaluate(x_test,y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0113
# [0.012032246217131615, 1.0]

# %%
Input = keras.Input(shape=(2,))
x = layers.Dense(10,activation='relu')(Input)
x = layers.Dense(20,activation='relu')(x)
x = layers.Dense(10,activation='relu')(x)
output = layers.Dense(1,activation='sigmoid')(x)

model = keras.Model(inputs = Input, outputs = output)

print(model.summary())

model.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate = 0.001),
    metrics = ["accuracy"]
)
history = model.fit(x_train,y_train,batch_size=80,epochs=100,validation_data=(x_test,y_test))
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4706 - loss: 0.7046 - val_accuracy: 0.4500 - val_loss: 0.7003
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4866 - loss: 0.6956 - val_accuracy: 0.3850 - val_loss: 0.7002
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4398 - loss: 0.6910 - val_accuracy: 0.4250 - val_loss: 0.6997
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4845 - loss: 0.6900 - val_accuracy: 0.4600 - val_loss: 0.6993
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4633 - loss: 0.6919 - val_accuracy: 0.4650 - val_loss: 0.6987
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5004 - loss: 0.6903 - val_accuracy: 0.4600 - val_loss: 0.6987
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4981 - loss: 0.6885 - val_accuracy: 0.4650 - val_loss: 0.6986
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5070 - loss: 0.6879 - val_accuracy: 0.4600 - val_loss: 0.6984
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5014 - loss: 0.6878 - val_accuracy: 0.4600 - val_loss: 0.6980
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5237 - loss: 0.6855 - val_accuracy: 0.4750 - val_loss: 0.6978
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5283 - loss: 0.6846 - val_accuracy: 0.4750 - val_loss: 0.6975
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5206 - loss: 0.6853 - val_accuracy: 0.4900 - val_loss: 0.6967
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5300 - loss: 0.6840 - val_accuracy: 0.4900 - val_loss: 0.6964
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5465 - loss: 0.6808 - val_accuracy: 0.4900 - val_loss: 0.6957
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5305 - loss: 0.6805 - val_accuracy: 0.4950 - val_loss: 0.6948
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5510 - loss: 0.6786 - val_accuracy: 0.4950 - val_loss: 0.6943
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5315 - loss: 0.6840 - val_accuracy: 0.5100 - val_loss: 0.6921
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5263 - loss: 0.6814 - val_accuracy: 0.5150 - val_loss: 0.6915
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5378 - loss: 0.6770 - val_accuracy: 0.4950 - val_loss: 0.6906
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5572 - loss: 0.6738 - val_accuracy: 0.5250 - val_loss: 0.6894
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5543 - loss: 0.6733 - val_accuracy: 0.5250 - val_loss: 0.6876
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5524 - loss: 0.6753 - val_accuracy: 0.5250 - val_loss: 0.6857
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5073 - loss: 0.6776 - val_accuracy: 0.5300 - val_loss: 0.6834
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5531 - loss: 0.6701 - val_accuracy: 0.5250 - val_loss: 0.6825
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5306 - loss: 0.6710 - val_accuracy: 0.5300 - val_loss: 0.6801
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5733 - loss: 0.6646 - val_accuracy: 0.5350 - val_loss: 0.6784
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5685 - loss: 0.6623 - val_accuracy: 0.5350 - val_loss: 0.6731
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5744 - loss: 0.6582 - val_accuracy: 0.5450 - val_loss: 0.6683
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5906 - loss: 0.6541 - val_accuracy: 0.5500 - val_loss: 0.6628
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5961 - loss: 0.6502 - val_accuracy: 0.5700 - val_loss: 0.6571
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6106 - loss: 0.6427 - val_accuracy: 0.5600 - val_loss: 0.6534
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6393 - loss: 0.6335 - val_accuracy: 0.6800 - val_loss: 0.6433
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7302 - loss: 0.6294 - val_accuracy: 0.7050 - val_loss: 0.6355
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7606 - loss: 0.6218 - val_accuracy: 0.7350 - val_loss: 0.6264
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7698 - loss: 0.6158 - val_accuracy: 0.7550 - val_loss: 0.6156
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7896 - loss: 0.6077 - val_accuracy: 0.7800 - val_loss: 0.6026
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8167 - loss: 0.5893 - val_accuracy: 0.8450 - val_loss: 0.5860
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8374 - loss: 0.5741 - val_accuracy: 0.7850 - val_loss: 0.5753
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8363 - loss: 0.5505 - val_accuracy: 0.8550 - val_loss: 0.5567
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8665 - loss: 0.5386 - val_accuracy: 0.8450 - val_loss: 0.5375
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8730 - loss: 0.5198 - val_accuracy: 0.8900 - val_loss: 0.5116
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8994 - loss: 0.4946 - val_accuracy: 0.8900 - val_loss: 0.4907
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8999 - loss: 0.4712 - val_accuracy: 0.9400 - val_loss: 0.4534
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9504 - loss: 0.4453 - val_accuracy: 0.9750 - val_loss: 0.4216
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9762 - loss: 0.4073 - val_accuracy: 1.0000 - val_loss: 0.3850
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9854 - loss: 0.3721 - val_accuracy: 0.9950 - val_loss: 0.3595
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9882 - loss: 0.3412 - val_accuracy: 1.0000 - val_loss: 0.3281
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9905 - loss: 0.3177 - val_accuracy: 0.9950 - val_loss: 0.3018
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9862 - loss: 0.2900 - val_accuracy: 1.0000 - val_loss: 0.2646
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9976 - loss: 0.2528 - val_accuracy: 1.0000 - val_loss: 0.2410
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9977 - loss: 0.2194 - val_accuracy: 1.0000 - val_loss: 0.2105
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9995 - loss: 0.2041 - val_accuracy: 1.0000 - val_loss: 0.1888
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9988 - loss: 0.1788 - val_accuracy: 1.0000 - val_loss: 0.1691
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9992 - loss: 0.1622 - val_accuracy: 1.0000 - val_loss: 0.1577
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1498 - val_accuracy: 1.0000 - val_loss: 0.1398
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9977 - loss: 0.1381 - val_accuracy: 1.0000 - val_loss: 0.1333
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9996 - loss: 0.1257 - val_accuracy: 1.0000 - val_loss: 0.1172
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.1159 - val_accuracy: 1.0000 - val_loss: 0.1053
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.1022 - val_accuracy: 1.0000 - val_loss: 0.0999
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0946 - val_accuracy: 1.0000 - val_loss: 0.0897
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9963 - loss: 0.0871 - val_accuracy: 1.0000 - val_loss: 0.0839
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0801 - val_accuracy: 1.0000 - val_loss: 0.0763
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0746 - val_accuracy: 1.0000 - val_loss: 0.0703
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0704 - val_accuracy: 1.0000 - val_loss: 0.0662
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9989 - loss: 0.0657 - val_accuracy: 1.0000 - val_loss: 0.0609
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0603 - val_accuracy: 1.0000 - val_loss: 0.0574
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0593 - val_accuracy: 1.0000 - val_loss: 0.0540
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0514 - val_accuracy: 1.0000 - val_loss: 0.0487
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0497 - val_accuracy: 1.0000 - val_loss: 0.0466
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0467 - val_accuracy: 1.0000 - val_loss: 0.0420
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0441 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0400 - val_accuracy: 1.0000 - val_loss: 0.0374
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0365
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 1.0000 - val_loss: 0.0311
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0300
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0265
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0243
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0230
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0209
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0202
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0196
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0168
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.0160
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0127
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0114

# %%
model.inputs
# Out:
# [<KerasTensor shape=(None, 2), dtype=float32, sparse=False, ragged=False, name=keras_tensor_31>]

# %%
model.layers
# Out:
# [<InputLayer name=input_layer_5, built=True>,
#  <Dense name=dense_20, built=True>,
#  <Dense name=dense_21, built=True>,
#  <Dense name=dense_22, built=True>,
#  <Dense name=dense_23, built=True>]

# %%
model.layers[-3].output
# Out:
# <KerasTensor shape=(None, 20), dtype=float32, sparse=False, ragged=False, name=keras_tensor_33>

# %%
# new_model = keras.Model(inputs = model.inputs,
#                         outputs = model.get_layer('dense_6').output)
new_model = keras.Model(inputs = model.inputs,
                        outputs = [model.layers[-2].output,model.layers[-1].output])
print(new_model.summary())

features = new_model.predict(x_test)
# for feat in features:
#     print(feat.shape)
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 2)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 10)                  │              30 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 20)                  │             220 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 10)                  │             210 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 471 (1.84 KB)
#  Trainable params: 471 (1.84 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# C:\Users\abhis\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_31']
# Received: inputs=Tensor(shape=(32, 2))
#   warnings.warn(msg)
# C:\Users\abhis\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_31']
# Received: inputs=Tensor(shape=(None, 2))
#   warnings.warn(msg)

# %%
features[0].shape
# Out:
# (200, 10)

# %%
features[1].shape
# Out:
# (200, 1)

# %%
features
# Out:
# [array([[0.22146563, 0.01266447, 1.0553937 , ..., 1.0105437 , 1.2567867 ,
#          1.4345058 ],
#         [1.2500628 , 0.6549707 , 0.24646252, ..., 0.1890907 , 0.36066082,
#          0.43587115],
#         [0.        , 0.        , 1.1638615 , ..., 1.1790868 , 1.3786927 ,
#          1.7787756 ],
#         ...,
#         [0.25167146, 0.02541424, 1.3640125 , ..., 1.2520813 , 1.4387994 ,
#          1.3777487 ],
#         [1.2063204 , 0.5315815 , 0.10980371, ..., 0.13493463, 0.18618405,
#          0.3121315 ],
#         [1.6345531 , 0.89142567, 0.20580894, ..., 0.07077329, 0.14182207,
#          0.        ]], dtype=float32),
#  array([[5.0497493e-03],
#         [9.8855931e-01],
#         [6.3212099e-04],
#         [3.9922381e-03],
#         [2.4111185e-02],
#         [9.6206248e-01],
#         [9.9712862e-03],
#         [9.9836802e-01],
#         [2.2471164e-04],
#         [9.9392033e-01],
#         [3.8459044e-04],
#         [9.9870849e-01],
#         [9.9679679e-01],
#         [4.0406115e-02],
#         [1.7950382e-02],
#         [1.0829051e-03],
#         [1.6741540e-02],
#         [9.7721708e-01],
#         [1.1726180e-03],
#         [9.9497956e-01],
#         [9.8923588e-01],
#         [9.7309548e-01],
#         [9.9887973e-01],
#         [8.8631110e-03],
#         [2.3367172e-04],
#         [1.5716523e-02],
#         [1.1279280e-03],
#         [5.1052112e-04],
#         [9.9975485e-01],
#         [9.8964153e-04],
#         [9.9347502e-01],
#         [2.7473513e-03],
#         [9.9972743e-01],
#         [9.8887229e-01],
#         [9.9637431e-01],
#         [1.2742257e-03],
#         [4.6340734e-02],
#         [9.8368728e-01],
#         [9.9938375e-01],
#         [9.9570721e-01],
#         [1.3634819e-03],
#         [3.4708495e-04],
#         [9.9961066e-01],
#         [5.7712410e-02],
#         [9.9808836e-01],
#         [1.9405042e-03],
#         [1.2350401e-02],
#         [6.9149889e-02],
#         [9.9965119e-01],
#         [2.8955258e-04],
#         [6.1739548e-03],
#         [6.9156656e-04],
#         [2.4593446e-02],
#         [9.9811929e-01],
#         [7.0723090e-03],
#         [9.9947757e-01],
#         [5.1256311e-03],
#         [4.6147057e-03],
#         [9.9111813e-01],
#         [2.0931656e-03],
#         [6.5486616e-04],
#         [1.1199339e-03],
#         [9.9769288e-01],
#         [5.3068516e-03],
#         [9.9792802e-01],
#         [2.3453068e-03],
#         [5.2603363e-04],
#         [2.7801409e-02],
#         [9.4976151e-01],
#         [1.5542502e-04],
#         [2.4858847e-02],
#         [9.9658340e-01],
#         [9.8960370e-01],
#         [2.4248140e-03],
#         [9.7300291e-01],
#         [9.3182272e-05],
#         [9.8970497e-01],
#         [9.9882776e-01],
#         [8.3907899e-03],
#         [9.9719298e-01],
#         [9.9344987e-01],
#         [9.8599482e-01],
#         [6.9149799e-04],
#         [4.1982569e-03],
#         [9.9950141e-01],
#         [4.1457615e-03],
#         [9.7264218e-01],
#         [9.9756569e-01],
#         [9.9981290e-01],
#         [9.9844795e-01],
#         [9.9560177e-01],
#         [9.9815685e-01],
#         [9.9769324e-01],
#         [9.9623698e-01],
#         [3.3923793e-03],
#         [8.6569899e-01],
#         [9.9834722e-01],
#         [1.5021463e-04],
#         [5.6877913e-04],
#         [5.5105060e-02],
#         [9.9850553e-01],
#         [9.8042470e-01],
#         [9.9793482e-01],
#         [2.6962385e-04],
#         [9.8875493e-01],
#         [1.1500353e-02],
#         [9.9013019e-01],
#         [9.7991061e-01],
#         [1.1703967e-03],
#         [9.9972624e-01],
#         [1.6604967e-02],
#         [9.9756736e-01],
#         [9.9966812e-01],
#         [3.2469092e-03],
#         [2.3054058e-04],
#         [1.6134787e-02],
#         [9.5477310e-04],
#         [6.7679491e-04],
#         [9.7862798e-01],
#         [1.9023770e-02],
#         [9.4359320e-01],
#         [5.7579808e-02],
#         [8.5962592e-03],
#         [5.3915731e-04],
#         [8.4434050e-01],
#         [9.9810755e-01],
#         [5.8989976e-02],
#         [1.1086788e-03],
#         [9.6983409e-01],
#         [9.9963570e-01],
#         [2.0878421e-02],
#         [9.9002105e-01],
#         [9.8980701e-01],
#         [2.2514360e-02],
#         [9.9768311e-01],
#         [5.9469213e-04],
#         [5.8707163e-02],
#         [9.9792081e-01],
#         [9.9817485e-01],
#         [9.9831820e-01],
#         [9.7096723e-01],
#         [9.9733078e-01],
#         [9.9962097e-01],
#         [8.8420010e-04],
#         [1.9169917e-02],
#         [9.9610317e-01],
#         [9.9834138e-01],
#         [9.9872005e-01],
#         [1.3690352e-02],
#         [9.8149019e-01],
#         [9.9928427e-01],
#         [9.9335235e-01],
#         [1.7922046e-03],
#         [9.9751461e-01],
#         [6.3443449e-03],
#         [9.9310517e-01],
#         [9.9807364e-01],
#         [5.7681970e-02],
#         [1.2256970e-03],
#         [6.9844779e-03],
#         [9.9304080e-01],
#         [9.9944437e-01],
#         [9.9343032e-01],
#         [9.9979061e-01],
#         [8.5067947e-04],
#         [9.7426242e-01],
#         [4.1637970e-03],
#         [3.9184717e-03],
#         [3.3086702e-02],
#         [9.9988133e-01],
#         [9.9788642e-01],
#         [4.4224663e-03],
#         [1.7449186e-03],
#         [9.9924630e-01],
#         [9.8499441e-01],
#         [9.7709185e-01],
#         [9.9688393e-01],
#         [8.1808725e-03],
#         [9.9815750e-01],
#         [9.9545896e-01],
#         [9.8726034e-01],
#         [9.9908543e-01],
#         [9.9657816e-01],
#         [4.0183272e-03],
#         [2.5675106e-03],
#         [2.2079193e-04],
#         [9.9680930e-01],
#         [9.9906808e-01],
#         [9.9206144e-01],
#         [9.6255845e-01],
#         [9.1856486e-01],
#         [5.6109385e-04],
#         [5.4160022e-04],
#         [9.8944342e-01],
#         [9.9781674e-01],
#         [9.8251754e-01],
#         [2.3112271e-03],
#         [9.5240638e-04],
#         [9.8850536e-01],
#         [9.9856186e-01]], dtype=float32)]
