# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples=500,n_features=2,centers = 5,random_state=20)

# %%
plt.scatter(X[:,0],X[:,1],c = y)
plt.show()

# %%
def initialize_cluster(k = 2,n_features = 2,min = -10,max = 10):
    clusters = []
    for i in range(k):
        cluster = {}
        cluster['center'] = (max-min)*np.random.rand(n_features)+min
        cluster['points'] = []
        clusters.append(cluster)
    return clusters

# %%
clusters = initialize_cluster(5,2,np.array([-10,-5]),np.array([10,5]))
clusters
# Out:
# [{'center': array([-1.82778579, -0.82602799]), 'points': []},
#  {'center': array([ 0.99494859, -2.51314946]), 'points': []},
#  {'center': array([-4.0106389 , -2.99771456]), 'points': []},
#  {'center': array([0.51414807, 4.97631999]), 'points': []},
#  {'center': array([7.02420329, 3.72209045]), 'points': []}]

# %%
def distance(p1,p2):
    return np.sqrt(np.sum((p2-p1)**2))

# %%
def assign_points(X,clusters):
    for i in range(X.shape[0]):
        dist = []
        for c in clusters:
            dist.append(distance(X[i],c['center']))
        clusters[np.argmin(dist)]['points'].append(X[i])

# %%
assign_points(X,clusters)
clusters
# Out:
# [{'center': array([-1.82778579, -0.82602799]),
#   'points': [array([-4.49009116,  1.05572831]),
#    array([-4.12555975,  2.4397487 ]),
#    array([-5.08617397,  1.84880819]),
#    array([-2.8132828 ,  1.94473949]),
#    array([-9.56253716,  4.86143849]),
#    array([-3.37128375, -0.3250539 ]),
#    array([-9.08089007,  5.09269571]),
#    array([-3.82397809,  1.2578119 ]),
#    array([-2.04619499,  1.07163662]),
#    array([-2.64993547, -0.53026019]),
#    array([-8.12570561,  4.57510771]),
#    array([-4.25498327,  0.91334429]),
#    array([-9.02519571,  4.59657159]),
#    array([-2.54899281, -0.42922033]),
#    array([-1.92712183,  1.01107666]),
#    array([-8.04240815,  4.32654212]),
#    array([-2.47400949,  0.48832554]),
#    array([-2.31143147,  0.54689481]),
#    array([-2.51674906, -0.27981768]),
#    array([-2.95834997,  0.48999186]),
#    array([-1.89657615,  1.84628576]),
#    array([-3.74336314,  0.8008338 ]),
#    array([-2.21300856,  2.6723961 ]),
#    array([-3.18064334, -0.01474341]),
#    array([-2.68414929,  0.5255511 ]),
#    array([-2.0671857 , -1.22269221]),
#    array([-9.57924619,  4.80085582]),
#    array([-4.38288385, -0.23778275]),
#    array([-3.68197443,  0.80197887]),
#    array([-1.88304759,  0.12612045]),
#    array([-3.23534937,  1.40165337]),
#    array([-3.45131811, -1.0739219 ]),
#    array([-1.90089193,  1.43494703]),
#    array([-1.31218012, -0.05057673]),
#    array([-1.5116    , -0.09203165]),
#    array([-7.13366757,  4.2421557 ]),
#    array([-3.13334945, -1.0581589 ]),
#    array([-2.89118409, -1.28515167]),
#    array([-2.69771934, -0.37811321]),
#    array([-3.97973281, -0.49563377]),
#    array([-9.61989685,  5.12389412]),
#    array([-2.57246481,  1.29260351]),
#    array([-3.66895829,  1.63750748]),
#    array([-3.36145653,  0.59097628]),
#    array([-2.4693527 ,  0.20979252]),
#    array([-9.13665782,  5.17361149]),
#    array([-1.77135715,  1.2945223 ]),
#    array([-8.63318184,  5.00452474]),
#    array([-2.72939016e+00,  1.54638424e-03]),
#    array([-2.75600998, -0.95656925]),
#    array([-3.56656576,  0.4810682 ]),
#    array([-0.29483158, -0.17422094]),
#    array([-8.05193011,  2.54143333]),
#    array([-10.37593325,   4.27275069]),
#    array([-9.28518271,  3.73389615]),
#    array([-9.36032252,  3.1031832 ]),
#    array([-10.82093001,   5.13225998]),
#    array([-8.57793608,  3.01417734]),
#    array([-9.23524961,  3.38941472]),
#    array([-8.91850483,  2.81973367]),
#    array([-9.72385412,  4.27487812])]},
#  {'center': array([0.51414807, 4.97631999]),
#   'points': [array([2.05217517, 7.48406522]),
#    array([2.25605326, 5.24990931]),
#    array([0.80040004, 7.47182365]),
#    array([2.10074237, 8.06333734]),
#    array([3.85728136, 8.31370355]),
#    array([1.77384736, 6.86484509]),
#    array([2.24093253, 7.23908406]),
#    array([0.87712287, 6.84969507]),
#    array([2.37253382, 7.8770468 ]),
#    array([2.66607902, 6.40911521]),
#    array([2.85450263, 8.88886541]),
#    array([2.11110489, 8.40339271]),
#    array([-0.02355261,  7.84261726]),
#    array([1.89139437, 5.88732584]),
#    array([2.28968574, 6.40317382]),
#    array([0.82370553, 6.05281051]),
#    array([0.93392325, 8.06832216]),
#    array([-9.39087826,  5.75578229]),
#    array([3.12912175, 6.59105457]),
#    array([1.72143588, 7.68394766]),
#    array([2.70208537, 6.97579352]),
#    array([1.20743022, 7.95578312]),
#    array([1.98127374, 7.5613926 ]),
#    array([2.08607703, 7.46086368]),
#    array([-8.54408994,  5.27839965]),
#    array([0.90784053, 7.44112945]),
#    array([3.62547116, 7.65904408]),
#    array([1.65680297, 9.96417617]),
#    array([2.19167006, 8.39066296]),
#    array([2.8137247 , 8.36064298]),
#    array([1.23053677, 9.08003341]),
#    array([2.20064052, 9.31206357]),
#    array([1.71842122, 9.52190711]),
#    array([2.03469291, 8.02934857]),
#    array([2.58780065, 9.77647999]),
#    array([3.58975755, 6.86777078]),
#    array([1.5429549 , 9.45767271]),
#    array([3.06404542, 6.95947265]),
#    array([0.70644702, 8.50854949]),
#    array([2.61970984, 9.4354182 ]),
#    array([3.30025999, 6.92264204]),
#    array([2.40965011, 8.54749177]),
#    array([2.81550794, 7.86080327]),
#    array([1.80080849, 8.94376112]),
#    array([3.71804812, 7.56269914]),
#    array([0.28023097, 7.09811034]),
#    array([2.45361814, 6.46855495]),
#    array([1.52314626, 8.41401879]),
#    array([1.05083046, 9.39735757]),
#    array([1.91519521, 9.1842175 ]),
#    array([2.60423854, 8.20582745]),
#    array([2.26571286, 8.36068903]),
#    array([1.84943529, 5.43892028]),
#    array([1.78398506, 8.54868999]),
#    array([1.39755858, 8.4510448 ]),
#    array([0.2586382 , 9.26824239]),
#    array([1.358082  , 9.10319957]),
#    array([2.29034449, 8.11011278]),
#    array([0.82767806, 6.34128434]),
#    array([1.59396992, 4.76457177]),
#    array([2.82105811, 8.70143965]),
#    array([2.40904619, 8.44167752]),
#    array([2.26505125, 9.11624047]),
#    array([2.99990895, 8.79466321]),
#    array([1.86140464, 7.72595353]),
#    array([3.6126599, 7.7784681]),
#    array([2.51492934, 6.61935379]),
#    array([0.32366548, 7.64300565]),
#    array([1.32435583, 9.37477301]),
#    array([0.14671681, 7.10230996]),
#    array([-0.17865027,  8.29570927]),
#    array([0.81259801, 8.81227391]),
#    array([2.9671273 , 9.30607075]),
#    array([1.65359865, 9.510461  ]),
#    array([1.160308  , 9.49900292]),
#    array([0.1331145 , 6.13901875]),
#    array([1.77826968, 8.85893477]),
#    array([0.24810506, 7.39451325]),
#    array([2.85804937, 7.62073077]),
#    array([1.42412542, 8.27524534]),
#    array([2.09222936, 6.81774802]),
#    array([1.51927726, 7.82424385]),
#    array([1.73248992, 8.58928763]),
#    array([ 2.69548237, 10.01411256]),
#    array([0.32076745, 6.53760781]),
#    array([2.56828526, 7.94172362]),
#    array([1.3530446, 9.4016816]),
#    array([3.20409392, 8.22310679]),
#    array([2.88274828, 9.28705277]),
#    array([3.36860866, 7.80061273]),
#    array([1.53391876, 6.37801968]),
#    array([2.4867433 , 7.77411525]),
#    array([1.50179311, 7.06479682]),
#    array([0.97059923, 7.11190662]),
#    array([0.6478754, 7.0310672]),
#    array([-8.94789426,  5.71657252]),
#    array([1.90623866, 8.70457249]),
#    array([0.95571493, 7.2479642 ]),
#    array([-8.69434776,  5.39443442]),
#    array([-7.37712043,  4.7878221 ]),
#    array([0.48311336, 8.19998973]),
#    array([2.43925569, 8.78538034]),
#    array([-0.19927622,  6.10223631]),
#    array([1.88333823, 8.36829966]),
#    array([1.92844903, 8.74307137])]},
#  {'center': array([7.02420329, 3.72209045]),
#   'points': [array([7.53383924, 7.50611744]),
#    array([8.3015357 , 7.96423462]),
#    array([9.28739238, 5.26966125]),
#    array([7.59893476, 6.06912365]),
#    array([8.59240069, 4.6699058 ]),
#    array([9.00005159, 6.04093467]),
#    array([8.9262464 , 6.89619448]),
#    array([6.93230709, 7.05195172]),
#    array([8.37218704, 6.17164224]),
#    array([8.75459274, 4.71536869]),
#    array([6.66754848, 7.07652492]),
#    array([6.78186345, 5.25729333]),
#    array([7.7123211 , 5.95627657]),
#    array([5.31883388, 5.89947773]),
#    array([8.85147962, 8.28867144]),
#    array([5.76212109, 7.65029208]),
#    array([7.6663133 , 6.71081207]),
#    array([8.68454095, 6.30878962]),
#    array([7.34008143, 7.49792041]),
#    array([7.98643821, 6.87236095]),
#    array([8.74037128, 7.76327114]),
#    array([7.63724607, 6.67306224]),
#    array([7.19791322, 5.95722287]),
#    array([8.20201554, 6.75633495]),
#    array([8.77304409, 7.19657208]),
#    array([8.39725419, 5.54035572]),
#    array([8.26151529, 7.7917359 ]),
#    array([9.21827723, 7.85430227]),
#    array([6.49003725, 6.0054937 ]),
#    array([6.76198247, 7.20746693]),
#    array([8.46802276, 4.70731993]),
#    array([7.59657155, 6.06137658]),
#    array([7.94984462, 5.372138  ]),
#    array([7.08708149, 5.39271097]),
#    array([8.9214594 , 6.35367568]),
#    array([7.76385499, 5.38277771]),
#    array([7.48384995, 7.24015501]),
#    array([7.5248663 , 8.02903231]),
#    array([7.70829865, 6.53591912]),
#    array([7.17296751, 6.08978595]),
#    array([8.18304682, 5.41493358]),
#    array([7.44398228, 6.33965135]),
#    array([8.02367204, 5.47191581]),
#    array([7.36048205, 8.26149705]),
#    array([7.71536041, 5.97010247]),
#    array([8.0382696 , 6.16748365]),
#    array([7.07708323, 6.40624289]),
#    array([7.45870672, 5.2773322 ]),
#    array([8.63490934, 7.71814114]),
#    array([7.64581332, 8.50909068]),
#    array([8.88597898, 7.43204248]),
#    array([8.94945134, 6.00828543]),
#    array([7.29118383, 6.90788229]),
#    array([7.42375668, 5.08553627]),
#    array([8.32245518, 7.32045814]),
#    array([6.26054596, 7.30272964]),
#    array([8.97141369, 6.44650455]),
#    array([7.05653976, 5.24582714]),
#    array([9.87066634, 6.73277697]),
#    array([9.13545281, 6.96597772]),
#    array([7.56270718, 5.36518694]),
#    array([9.16144501, 5.29724521]),
#    array([8.50073105, 5.16787686]),
#    array([9.63162099, 6.12233072]),
#    array([8.09600612, 8.23166119]),
#    array([7.45375612, 6.18827529]),
#    array([7.10837618, 8.43846241]),
#    array([7.11807048, 6.64027114]),
#    array([7.97408167, 7.75159431]),
#    array([6.28795018, 7.32083002]),
#    array([9.3553878 , 7.52353709]),
#    array([7.20367725, 5.23938641]),
#    array([6.99907065, 5.64400294]),
#    array([6.871928  , 5.98308486]),
#    array([8.12620096, 5.90448054]),
#    array([7.17587081, 6.48758134]),
#    array([7.56504084, 5.27615644]),
#    array([6.98842755, 5.16857487]),
#    array([9.24510576, 4.70695221]),
#    array([7.32242309, 5.82153378]),
#    array([7.12249109, 7.73088903]),
#    array([8.97714638, 6.84380574]),
#    array([5.88340472, 6.20886032]),
#    array([6.85314906, 7.23848591]),
#    array([8.06586619, 6.22418976]),
#    array([7.81583555, 7.44319565]),
#    array([6.84804548, 4.94311319]),
#    array([7.49731366, 7.24511153]),
#    array([7.31955141, 6.91057222]),
#    array([7.3530819 , 6.19454707]),
#    array([9.08211044, 5.92528417]),
#    array([7.78368948, 4.85664337]),
#    array([6.80903186, 6.78902752]),
#    array([7.1389904 , 6.71228785]),
#    array([6.95511465, 4.97429314]),
#    array([9.10759443, 6.66321088]),
#    array([6.94113941, 6.67025718]),
#    array([6.41342514, 7.31722275]),
#    array([7.92737567, 7.40423345]),
#    array([7.84598323, 6.31610526])]}]

# %%
def plot_clusters(clusters):
    for cluster in clusters:
        if len(cluster['points']) != 0:
            p = np.array(cluster['points'])
            plt.scatter(p[:,0],p[:,1])
        c = cluster['center']
        plt.scatter(c[0],c[1],c = 'black')
    plt.show()

# %%
plot_clusters(clusters)

# %%
def update_clusters(clusters):
    is_updated = False
    for cluster in clusters:
        if len(cluster['points']) != 0:
            new_center = np.mean(cluster['points'],axis = 0)
            if np.any(new_center != cluster['center']):
                is_updated = True
                cluster['center'] = new_center
            
            cluster['points'] = []
    return is_updated

# %%
clusters = initialize_cluster(k = 5,n_features=2,min = np.min(X,axis = 0),max = np.max(X,axis = 0))
for i in range(10):
    assign_points(X,clusters)
    plot_clusters(clusters)
    is_updated = update_clusters(clusters)
    if is_updated == False:
        break

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
clf = KMeans(n_clusters=5)

# %%
clf.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
clf.inertia_
# Out:
# 944.4282081113831

# %%
clf.cluster_centers_
# Out:
# array([[-2.70399202,  0.46108905],
#        [ 7.78664491,  6.45659035],
#        [-9.41045484,  3.90984505],
#        [ 3.28857717, -6.15519417],
#        [ 1.86103043,  7.92313022]])

# %%
# clf.predict(X)

# %%
sil = []
wcss = []
for i in range(2,10):
    clf = KMeans(n_clusters=i)
    clf.fit(X)
    wcss.append(clf.inertia_)
    sil.append(silhouette_score(X,clf.predict(X)))

# %%
plt.plot([i for i in range(2,10)],wcss)

# %%
plt.plot([i for i in range(2,10)],sil)

# %%
clf
